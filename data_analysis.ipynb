# %%
import os
import pandas as pd
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns

# %%
years = os.listdir('/home/mirela/Documents/snake/SnakeCLEF2023-small_size')

# %%
len(years)
# Out:
# 34

# %%
df = []
y = 0
for year in tqdm(years):
    species = os.listdir(f'/home/mirela/Documents/snake/SnakeCLEF2023-small_size/{year}')
    for s in species:
        current_s = os.listdir(f'/home/mirela/Documents/snake/SnakeCLEF2023-small_size/{year}/{s}')
        number = len(current_s)
        df.append({'year': year, 'species': s, 'num': number})
# Out:
# 100%|███████████████████████████████████████████| 34/34 [00:01<00:00, 23.79it/s]

# %%
data = pd.DataFrame(df)

# %%
distribution = data.groupby('species', as_index=False).num.sum().sort_values(by='num')

# %%
distribution['num'].sum()
# Out:
# 153590

# %%
distribution['num'].mean()
# Out:
# 86.09304932735427

# %%
distribution['num'].median()
# Out:
# 49.5

# %%
distribution['num'].min(), distribution['num'].max()
# Out:
# (3, 1889)

# %%
plt.figure(figsize=(10, 5))
plt.hist(distribution['num'], bins=50, edgecolor='k', alpha=0.7)
plt.title('Distribution of Image Counts per Species')
plt.xlabel('Number of Images')
plt.ylabel('Number of Species')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 4))
sns.boxplot(x=distribution['num'])
plt.title('Box Plot of Image Counts per Snake Species')
plt.xlabel('Number of Images')
plt.grid(True)
plt.show()

# %% [markdown]
# # Country encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
metadata = pd.read_csv('./metadata.csv')

# %%
metadata.groupby('binomial_name').country.unique()
# Out:
# binomial_name
# Acanthophis antarcticus    [South Australia, New South Wales, Queensland,...
# Acanthophis laevis           [Maluku, Western Province, Papua, Maluku Utara]
# Acanthophis praelongus                                          [Queensland]
# Acanthophis pyrrhus                  [Northern Territory, Western Australia]
# Acanthophis rugosus                         [Northern Territory, Queensland]
#                                                  ...
# Zamenis lineatus           [Sicily, Latium, Apulia, Campania, Molise, Bas...
# Zamenis longissimus        [Languedoc-Roussillon, Central Bohemia, Midi-P...
# Zamenis persicus                                      [Mazandaran, Lankaran]
# Zamenis scalaris           [Languedoc-Roussillon, Castille and Leon, Midi...
# Zamenis situla             [Primorsko-Goranska, Crete, Central Macedonia,...
# Name: country, Length: 1572, dtype: object

# %%
metadata
# Out:
#         observation_id  endemic                binomial_name        country  \
# 0              2670823     True             Zamenis lineatus         Sicily
# 1             96294178    False             Liasis olivaceus     Queensland
# 2             70108926    False        Xenoxybelis argenteus       Amazonas
# 3             70108926    False        Xenoxybelis argenteus       Amazonas
# 4               117935    False          Aspidelaps lubricus  Northern Cape
# ...                ...      ...                          ...            ...
# 270246       106432247    False              Boa constrictor        Cordoba
# 270247       106432247    False              Boa constrictor        Cordoba
# 270248       106432247    False              Boa constrictor        Cordoba
# 270249       106435822    False  Philothamnus semivariegatus  KwaZulu-Natal
# 270250       106435952    False            Dipsadoboa aulica  KwaZulu-Natal
#
#        code  class_id                                       file_path
# 0        IT      1567               1990/Zamenis_lineatus/3001242.jpg
# 1        AU       816            1990/Liasis_olivaceus/159953206.jpeg
# 2        VE      1561        1990/Xenoxybelis_argenteus/113910655.jpg
# 3        VE      1561        1990/Xenoxybelis_argenteus/113910659.jpg
# 4        ZA        81             1990/Aspidelaps_lubricus/168477.JPG
# ...     ...       ...                                             ...
# 270246   CO       136             2022/Boa_constrictor/178789489.jpeg
# 270247   CO       136             2022/Boa_constrictor/178789493.jpeg
# 270248   CO       136             2022/Boa_constrictor/178789501.jpeg
# 270249   ZA      1124  2022/Philothamnus_semivariegatus/178796098.jpg
# 270250   ZA       470            2022/Dipsadoboa_aulica/178796247.jpg
#
# [270251 rows x 7 columns]

# %%
def encode_labels(meta_file_path):
    
    metadata = pd.read_csv(meta_file_path)
    meta_cols = ['country', 'binomial_name']
    
    for col in meta_cols:
        encoder = LabelEncoder()
        metadata[col + '_encoded'] = encoder.fit_transform(metadata[col]) + 1
        
    return dict(zip(metadata.country, metadata.country_encoded))

# %%
encode_labels('./metadata.csv')
# Out:
# {'Sicily': 1759,
#  'Queensland': 1553,
#  'Amazonas': 62,
#  'Northern Cape': 1352,
#  'Karas': 881,
#  'Languedoc-Roussillon': 1009,
#  'Texas': 1902,
#  'South Sulawesi': 1814,
#  'Primorskiy': 1525,
#  'Sisaket': 1775,
#  'Bahia': 165,
#  'Limburg': 1039,
#  'Tamil Nadu': 1874,
#  'South-West Province': 1816,
#  'Primorsko-Goranska': 1526,
#  "Kotayk'i Marz": 950,
#  'Mara': 1130,
#  'North Carolina': 1334,
#  'Pennsylvania': 1462,
#  'Liguria': 1034,
#  'unknown': 2152,
#  'Piedmont': 1490,
#  'Otjozondjupa': 1424,
#  'Rajasthan': 1567,
#  'Gambela': 627,
#  'Apure': 91,
#  'Castille and Leon': 352,
#  'New Jersey': 1302,
#  'Florida': 606,
#  'Illinois': 783,
#  'Arizona': 113,
#  'Guanacaste': 678,
#  'Rayong': 1575,
#  'Chon Buri': 428,
#  'Bujumbura Mairie': 296,
#  'Upper Takutu-Upper Essequibo': 1978,
#  'Shabwah': 1736,
#  'Lempira': 1024,
#  'Oregon': 1409,
#  'Souss-Massa-Draa': 1800,
#  'California': 324,
#  'Heredia': 734,
#  'Arkansas': 114,
#  'Napo': 1278,
#  'Central Bohemia': 365,
#  'Montana': 1217,
#  'Victoria': 2030,
#  'Oaxaca': 1376,
#  "Ma'an": 1087,
#  'Midi-Pyrenees': 1188,
#  'South Carolina': 1803,
#  'New Mexico': 1303,
#  'Cartago': 348,
#  'Colorado': 455,
#  'Massachusetts': 1151,
#  'Tai Po': 1865,
#  'Pastaza': 1448,
#  'Bolivar': 259,
#  'Atsimo-Andrefana': 139,
#  'Presidente Hayes': 1523,
#  'Boqueron': 262,
#  'Canindeyu': 332,
#  'Ihorombe': 775,
#  'Baja California': 166,
#  'Baja California Sur': 167,
#  'Mississippi': 1200,
#  'Quintana Roo': 1559,
#  'Braga': 275,
#  'Anosy': 80,
#  'Western Cape': 2085,
#  'Saint-Louis': 1642,
#  'Neembucu': 1292,
#  'Misiones': 1199,
#  'Georgia': 638,
#  'Loreto': 1056,
#  'East Nusa Tenggara': 550,
#  'Trentino-Alto Adige': 1945,
#  'Kigoma': 929,
#  'Sava': 1719,
#  'Wisconsin': 2092,
#  'Washington': 2067,
#  'Chiang Mai': 413,
#  'Mexico': 1182,
#  'Alaotra Mangoro': 48,
#  'Limpopo': 1042,
#  'Saint John': 1632,
#  'Colon': 453,
#  'Tocantins': 1923,
#  'Hhohho': 738,
#  'Mpumalanga': 1236,
#  'Lampang': 1005,
#  'Menabe': 1175,
#  'Comayagua': 456,
#  'Tanga': 1877,
#  'Ontario': 1400,
#  'San Luis Potosi': 1677,
#  'Tamaulipas': 1872,
#  'West Greece': 2072,
#  'Falcon': 592,
#  'Coahuila': 447,
#  'Utah': 1984,
#  'Managua': 1112,
#  'Nevada': 1297,
#  'Matabeleland North': 1153,
#  'Alto Paraguay': 58,
#  'Kagera': 850,
#  'Eastern Cape': 553,
#  'Sonora': 1796,
#  'British Columbia': 284,
#  'Bocas del Toro': 253,
#  'Indiana': 792,
#  'Jalisco': 823,
#  'Stann Creek': 1829,
#  'Burgas': 301,
#  'KwaZulu-Natal': 977,
#  'England': 572,
#  'Aragon': 98,
#  'South Aegean': 1801,
#  'Orellana': 1410,
#  'Borough of Arima': 266,
#  'Campeche': 326,
#  'Santa Cruz': 1695,
#  'Valencia': 2002,
#  'Guyane': 699,
#  'Northern Territory': 1359,
#  'New South Wales': 1305,
#  'Andalusia': 72,
#  'Ranong': 1570,
#  'Baalbek-Hermel': 157,
#  'Peloponnese': 1458,
#  'Alberta': 50,
#  'Leiria': 1023,
#  'Bulawayo': 298,
#  'Beqaa': 226,
#  'Olancho': 1393,
#  'Cayo': 360,
#  'Bali': 175,
#  'Kentucky': 899,
#  'Aragua': 99,
#  'Catamarca': 356,
#  'Esmeraldas': 582,
#  'Itasy': 813,
#  'Boeny': 254,
#  'Vatovavy Fitovinany': 2013,
#  'Taiwan': 1868,
#  'Kuala Lumpur': 966,
#  'Kgalagadi': 904,
#  'Phangnga': 1473,
#  'Chiapas': 415,
#  'Santiago Metropolitan': 1702,
#  'Putumayo': 1541,
#  'Puntarenas': 1538,
#  'Mato Grosso do Sul': 1158,
#  'Para': 1441,
#  'Quiche': 1557,
#  'Sinaloa': 1766,
#  "Provence-Alpes-Cote d'Azur": 1531,
#  'Johor': 840,
#  'Blagoevgrad': 247,
#  'Phetchaburi': 1477,
#  'Taipei': 1866,
#  'Chihuahua': 417,
#  'Nakhon Ratchasima': 1269,
#  'Louisiana': 1064,
#  'Lower Austria': 1067,
#  'Sao Paulo': 1708,
#  'Karlovacka': 882,
#  'Alajuela': 45,
#  'West Java': 2073,
#  'Yucatan': 2117,
#  'South Province': 1812,
#  'Chuy': 437,
#  'Migori': 1190,
#  'Tabasco': 1858,
#  'San Salvador': 1683,
#  'Cusco': 486,
#  'Guayas': 689,
#  'Western Australia': 2084,
#  'Missouri': 1201,
#  'Kerala': 901,
#  'Diana': 515,
#  'Madre de Dios': 1094,
#  'Valle del Cauca': 2005,
#  'Catalonia': 355,
#  'Zilinsky': 2144,
#  'Limon': 1040,
#  'Tochigi': 1924,
#  'Santa Ana': 1692,
#  'San Pedro': 1681,
#  'Crimea': 476,
#  'San Jose': 1671,
#  'Boaco': 251,
#  'Gyeonggi-do': 701,
#  'Abruzzo': 4,
#  'Sabah': 1619,
#  'Gangwon-do': 628,
#  'Mato Grosso': 1157,
#  'Morelos': 1228,
#  'Trat': 1942,
#  'Zadarska': 2122,
#  'Al Batinah': 33,
#  'Rio Grande do Norte': 1592,
#  'Prachuap Khiri Khan': 1520,
#  'Masaya': 1146,
#  'Cerro Largo': 388,
#  'Oriental': 1412,
#  'Castille-La Mancha': 353,
#  'Yerevan': 2112,
#  'Jiangsu Sheng': 833,
#  'Veracruz': 2022,
#  'Mexico City': 1183,
#  'Almaty Oblysy': 53,
#  'Qaraghandy': 1544,
#  'Gracias a Dios': 661,
#  'Atlantico Norte (RAAN)': 135,
#  'Michigan': 1184,
#  'Central Serbia': 378,
#  'Tunapuna/Piarco': 1957,
#  'Pahang': 1432,
#  'North West': 1346,
#  'Central': 362,
#  'New Hampshire': 1300,
#  'Chaco': 393,
#  'Izabal': 817,
#  'Dodoma': 528,
#  'San Miguel': 1680,
#  'Zambezi': 2127,
#  'Panama': 1437,
#  'Rivas': 1598,
#  'Granada': 663,
#  "Amoron'i Mania": 65,
#  'Maharashtra': 1101,
#  'Sangha-Mbaere': 1689,
#  'Sonsonate': 1797,
#  'Lautem': 1020,
#  'Rhone-Alpes': 1586,
#  'Gujarat': 694,
#  'Ciego de Avila': 440,
#  'Tokyo': 1926,
#  'Meknes-Tafilalet': 1170,
#  'New York': 1306,
#  'Extremadura': 589,
#  'Gharb-Chrarda-Beni Hssen': 642,
#  'Wanchai': 2063,
#  'Pays de la Loire': 1452,
#  'Chuvashia': 436,
#  'Toledo': 1927,
#  'Antioquia': 84,
#  'Vermont': 2024,
#  'Baden-Wuerttemberg': 163,
#  'Morona-Santiago': 1231,
#  'Chungcheongnam-do': 434,
#  'Zamora-Chinchipe': 2130,
#  'Madang': 1091,
#  'Copperbelt': 463,
#  'Pernambuco': 1469,
#  'Tennessee': 1898,
#  'Donetsk': 531,
#  'Acre': 8,
#  'Lorri': 1058,
#  'Gauteng': 631,
#  'San Martin': 1679,
#  'Shirak': 1748,
#  'Hela': 730,
#  'Paijanne Tavastia': 1433,
#  'Durango': 539,
#  'Cuscatlan': 485,
#  'Aguascalientes': 22,
#  'Sarawak': 1713,
#  'South Australia': 1802,
#  'Central Ostrobothnia': 376,
#  'Milne Bay': 1192,
#  'Cochabamba': 449,
#  'Siem Reap': 1760,
#  'Nuevo Leon': 1368,
#  'Nueva Segovia': 1367,
#  'Mae Hong Son': 1097,
#  'Hesse': 736,
#  'Eastern': 552,
#  'Darien': 505,
#  'Oshana': 1416,
#  'Kunene': 971,
#  'Demerara-Mahaica': 511,
#  'Hardap': 719,
#  'Queretaro': 1555,
#  'North-West': 1348,
#  'Kansas': 874,
#  'Sucumbios': 1839,
#  'Harare': 717,
#  'Karnataka': 884,
#  'Carazo': 342,
#  'Chinandega': 420,
#  'Alabama': 43,
#  'Terengganu': 1899,
#  'Chernihiv': 409,
#  'Vaestra Goetaland': 1998,
#  'Manicaland': 1120,
#  'Pirkanmaa': 1493,
#  'Ohio': 1386,
#  'Diyala': 523,
#  'Campania': 325,
#  'Mehedinti': 1169,
#  'Central Region': 377,
#  'Nakhon Nayok': 1266,
#  'Veszprem': 2027,
#  'High-Basins': 740,
#  'Podlasie': 1501,
#  'Wales': 2061,
#  'Boumerdes': 271,
#  'Greater Poland Voivodeship': 668,
#  'Zlin': 2146,
#  'Santa Barbara': 1693,
#  'Manabi': 1111,
#  'Saskatchewan': 1715,
#  'Basilicate': 201,
#  'Central Kalimantan': 373,
#  'Licko-Senjska': 1032,
#  'Rio Grande do Sul': 1593,
#  'Guadalcanal': 674,
#  'East Macedonia and Thrace': 549,
#  'Smolyan': 1783,
#  'Phongsali': 1481,
#  'Champasak': 398,
#  'West Pomeranian Voivodeship': 2079,
#  'Harju': 720,
#  'Pedernales': 1456,
#  'Pinar del Rio': 1491,
#  'Aosta Valley': 88,
#  'Tuen Mun': 1953,
#  'Peten': 1472,
#  'Mojkovac': 1208,
#  'Opstina Savnik': 1404,
#  'Kharkiv': 911,
#  'Maranhao': 1132,
#  'Bar': 188,
#  'Eastern Highlands': 554,
#  'North Sumatra': 1345,
#  'North Sulawesi': 1344,
#  'Puno': 1537,
#  'Analanjirofo': 69,
#  'La Libertad': 987,
#  'Colima': 452,
#  'Lombardy': 1053,
#  'Al Kufrah': 39,
#  'Minas Gerais': 1194,
#  'Matanzas': 1156,
#  'Singida': 1769,
#  'San Juan/Laventille': 1674,
#  'Iringa': 800,
#  'Marsabit': 1144,
#  'Guerrero': 692,
#  'La Pampa': 989,
#  'Turkana': 1960,
#  'Veraguas': 2023,
#  'Gelderland': 636,
#  'Atlantico Sur': 136,
#  'Choco': 426,
#  'Thua Thien-Hue': 1907,
#  'Littoral': 1046,
#  'Faro': 596,
#  'Orange Walk': 1407,
#  'Loei': 1050,
#  'Cross River': 478,
#  'Yunnan': 2119,
#  'Pathum Thani': 1449,
#  'Corrientes': 469,
#  'El Beni': 562,
#  'Kakamega': 854,
#  'Ararat': 100,
#  'Brokopondo': 288,
#  'Virginia': 2043,
#  'Portalegre': 1512,
#  'Ongtustik Qazaqstan': 1399,
#  'Styria': 1834,
#  'Central Jutland': 372,
#  'Central Macedonia': 375,
#  'Greater Accra': 667,
#  'Kiev': 927,
#  'Northern Ostrobothnia': 1355,
#  'Belize': 221,
#  'Norte de Santander': 1330,
#  'Murcia': 1250,
#  'Antalya': 83,
#  'Bobonaro': 252,
#  'Ghanzi': 641,
#  'Nakhichevan': 1265,
#  "Vayots' Dzori Marz": 2016,
#  'Galicia': 626,
#  'Burgenland': 302,
#  'Galapagos': 624,
#  'Viana do Castelo': 2028,
#  "Syunik'i Marz": 1855,
#  'Mykolaiv': 1256,
#  "Geghark'unik'i Marz": 635,
#  'Scotland': 1725,
#  'Baladiyat ar Rayyan': 171,
#  'Liquica': 1044,
#  'Federal District': 597,
#  'Gansu Sheng': 629,
#  'Govi-Altay': 659,
#  'Phra Nakhon Si Ayutthaya': 1482,
#  'Mont-Liban': 1216,
#  'Nebraska': 1291,
#  'Mugla': 1239,
#  "Southern Nations, Nationalities, and People's Region": 1821,
#  'Afyonkarahisar': 17,
#  'Bourgogne': 272,
#  'South Denmark': 1805,
#  'Chiriqui': 423,
#  'Ticino': 1913,
#  'Cocle': 450,
#  'Ysyk-Koel': 2116,
#  'Hidalgo': 739,
#  'Goias': 651,
#  'Embera': 569,
#  'Nizjnij Novgorod': 1321,
#  'Michoacan': 1185,
#  'Jihocesky': 836,
#  'Sing Buri': 1768,
#  'Shandong Sheng': 1740,
#  'Imbabura': 786,
#  'Orange Free State': 1406,
#  'Balearic Islands': 174,
#  'Sint Eustatius': 1772,
#  'Escuintla': 580,
#  'Tibesti': 1911,
#  'Al Jizah': 38,
#  'Atsinanana': 141,
#  'Puebla': 1533,
#  'Chubut': 431,
#  'Mimaropa': 1193,
#  'Western Region': 2088,
#  'Espirito Santo': 584,
#  'Los Rios': 1060,
#  'Bogota D.C.': 255,
#  'Uva': 1993,
#  'Cordoba': 466,
#  'Buenos Aires': 294,
#  'Rio de Janeiro': 1596,
#  'Pichincha': 1489,
#  'Australian Capital Territory': 146,
#  'Entre Rios': 576,
#  'Uttar Pradesh': 1988,
#  'Oklahoma': 1392,
#  'Rocha': 1604,
#  'Ngounie': 1311,
#  'Upper Matsiatra': 1976,
#  'Western': 2082,
#  'Tolima': 1928,
#  'North Kalimantan': 1340,
#  'Omusati': 1397,
#  'Nacional': 1260,
#  'Saint Paul': 1638,
#  'Central Visayas': 380,
#  'Crete': 475,
#  'Agadez': 18,
#  'Latium': 1019,
#  'Eastern Tobago': 557,
#  'Monte Cristi': 1218,
#  'Rivera': 1599,
#  'Zacatecas': 2121,
#  'Kursk': 974,
#  'Jundubah': 842,
#  'Constanta': 460,
#  'Ash Shariqah': 124,
#  'Quebec': 1551,
#  'Zufar': 2148,
#  'Nakhon Si Thammarat': 1271,
#  'Monte Plata': 1219,
#  'Inagua': 788,
#  'Vladimir': 2047,
#  'Surat Thani': 1849,
#  'Belgorod': 220,
#  'Moskovskaya': 1234,
#  'Ile-de-France': 779,
#  'Tverskaya': 1963,
#  'North Dakota': 1336,
#  'Quneitra': 1560,
#  'Sara Buri': 1710,
#  'Valais': 2000,
#  'Arecibo': 107,
#  'Qubadli': 1550,
#  'Zangilan Rayon': 2131,
#  'Xocavand Rayonu': 2100,
#  'Limousin': 1041,
#  'Tartar Rayon': 1882,
#  'Kalbacar Rayonu': 857,
#  'Bavaria': 210,
#  'Baki': 169,
#  'Nayarit': 1289,
#  'Balakan Rayon': 173,
#  'Zaqatala': 2138,
#  'Saint Gallen': 1631,
#  'Aceh': 7,
#  'El Oro': 563,
#  'Astara': 128,
#  'Transbaikal Territory': 1939,
#  'Rjazan': 1603,
#  'Olomoucky': 1394,
#  'Mazandaran': 1164,
#  'Tatarstan': 1886,
#  'Wallonia': 2062,
#  'Zanzibar North': 2135,
#  'Tak': 1869,
#  'Corsica': 470,
#  'Republic of Karelia': 1578,
#  'Usulutan': 1983,
#  'Zealand': 2139,
#  'Sancti Spiritus': 1687,
#  'Kymenlaakso': 981,
#  'Khanty-Mansiyskiy Avtonomnyy Okrug': 910,
#  'Astrakhan': 129,
#  'Kedah': 895,
#  'Parana': 1445,
#  'Ogooue-Ivindo': 1381,
#  'Buenos Aires F.D.': 295,
#  'Tsuen Wan': 1951,
#  'Guelmim-Es Smara': 691,
#  'Shefa': 1743,
#  'Oued Ed-Dahab-Lagouira': 1426,
#  'Adrar': 14,
#  'Kars': 886,
#  'Maine': 1102,
#  'Melaky': 1172,
#  'Maryland': 1145,
#  'Ogooue-Maritime': 1383,
#  'Jeollabuk-do': 828,
#  'Khyber Pakhtunkhwa': 923,
#  'Asturias': 130,
#  'Palauli': 1435,
#  'English River': 573,
#  'Pasco': 1447,
#  'Northern Region': 1357,
#  'Manatuto': 1114,
#  'Prachin Buri': 1519,
#  'Sabaragamuwa': 1621,
#  'San Luis': 1676,
#  'Ratchaburi': 1574,
#  'Mendoza': 1176,
#  'Krabi': 956,
#  'Sofala': 1787,
#  'Phuket': 1486,
#  'Reunion': 1582,
#  'North Province': 1342,
#  'Zaire': 2124,
#  'Kgatleng': 905,
#  'Perak': 1465,
#  'Santo Domingo de los Tsachilas': 1707,
#  'Couva-Tabaquite-Talparo': 473,
#  'Magdalena': 1098,
#  'Barinas': 193,
#  'Saba': 1618,
#  'Atakora': 133,
#  'Salta': 1653,
#  'Santa Fe': 1697,
#  'North Western': 1347,
#  'Potaro-Siparuni': 1516,
#  'Erongo': 579,
#  'Yoro': 2115,
#  'Guarico': 685,
#  'Cahul': 318,
#  'Galati': 625,
#  'Kanchanaburi': 868,
#  'Rio Negro': 1594,
#  'Lara': 1013,
#  'Zaporizhia': 2137,
#  'Atlantico': 134,
#  'Tulcea': 1955,
#  'Brittany': 285,
#  'West Papua': 2078,
#  'Santiago de Cuba': 1704,
#  'Western Visayas': 2089,
#  'Rheinland-Pfalz': 1584,
#  'Loja': 1052,
#  'Mongar': 1212,
#  'Tacna': 1861,
#  'Sofia': 1788,
#  'Akershus': 30,
#  'Aquitaine': 94,
#  'Muhafazat al Fayyum': 1243,
#  'Minnesota': 1195,
#  'Fukuoka': 617,
#  'South Dakota': 1804,
#  'Poitou-Charentes': 1504,
#  'Roraima': 1608,
#  'Miranda': 1198,
#  'Chanthaburi': 404,
#  'Pozesko-Slavonska': 1518,
#  'North Aegean': 1331,
#  'Daejeon': 492,
#  'Ahuachapan': 24,
#  'Aragatsotn': 97,
#  'Namibe': 1274,
#  'Carinthia': 345,
#  'Manica': 1119,
#  'New Brunswick': 1299,
#  'Capital Region': 337,
#  'Cantabria': 334,
#  'Gyeongsangnam-do': 703,
#  'Huehuetenango': 759,
#  'Central Aimak': 364,
#  'Central Sulawesi': 379,
#  'Friuli Venezia Giulia': 613,
#  'Kamphaeng Phet': 862,
#  'Arunachal Pradesh': 120,
#  'Emilia-Romagna': 570,
#  'Kranjska Gora': 959,
#  'Ogun': 1385,
#  'Beja': 217,
#  'Likouala': 1036,
#  'Bioko Sur': 242,
#  'Thessaly': 1905,
#  'Veneto': 2021,
#  'Manitoba': 1124,
#  'Guanica': 682,
#  'Melaka': 1171,
#  'Anse Boileau': 81,
#  'Anse Royale': 82,
#  'La Rioja': 991,
#  'Chiang Rai': 414,
#  'Sa Kaeo': 1614,
#  'Formosa': 607,
#  'San Juan': 1673,
#  'Neuquen': 1296,
#  'Holguin': 748,
#  'Cortes': 471,
#  'Can Tho': 328,
#  'Telangana': 1894,
#  'Upper River': 1977,
#  'San Vicente': 1685,
#  'West Kalimantan': 2074,
#  'Bangkok': 183,
#  'Cesar': 389,
#  'Circonscription de Sigave': 442,
#  'Loyalty Islands': 1073,
#  'Southern': 1817,
#  'La Guajira': 985,
#  'Susah': 1851,
#  'Madrid': 1095,
#  'Khomas': 917,
#  'Rio Grande': 1591,
#  'Odisha': 1380,
#  'OErebro': 1374,
#  'Larnaka': 1015,
#  'Ramsey': 1569,
#  'Caraga': 340,
#  'Lam Dong': 1003,
#  'Marrakech-Tensift-Al Haouz': 1143,
#  'Kanagawa': 866,
#  'Atlantida': 137,
#  'Bauchi': 208,
#  'Cundinamarca': 484,
#  'Quindio': 1558,
#  'Bern': 230,
#  'Nong Khai': 1323,
#  'Xekong': 2097,
#  'Sha`biyat Nalut': 1734,
#  'Epirus': 577,
#  'Brandenburg': 278,
#  'Salavan': 1651,
#  'Gwangju': 700,
#  'Nara': 1279,
#  'West New Britain': 2076,
#  'Somogy': 1794,
#  'Irkutsk': 801,
#  'Iowa': 798,
#  'Penang': 1461,
#  'Asyut': 131,
#  'Suhaj': 1843,
#  'Miyagi': 1203,
#  'La Paz': 990,
#  'Chaguanas': 394,
#  'Sichuan': 1758,
#  'Caldas': 323,
#  'Santa Elena': 1696,
#  'Nord': 1326,
#  'Guanajuato': 679,
#  'Bashkortostan': 200,
#  'National Capital': 1286,
#  'Upper West': 1979,
#  'Koh Kong': 940,
#  'Zhytomyr': 2143,
#  'Lamphun': 1006,
#  'Eastern Visayas': 558,
#  'West Virginia': 2081,
#  'Lodz Voivodeship': 1049,
#  "Moore's Island": 1221,
#  'Lower Normandy': 1068,
#  'Rondonia': 1607,
#  'Volyn': 2052,
#  'East Gobi Aymag': 544,
#  'Maria Trinidad Sanchez': 1134,
#  'Arusha': 121,
#  'OEstergoetland': 1375,
#  'Madanin': 1092,
#  'New Ireland': 1301,
#  'Phayao': 1475,
#  'Chungcheongbuk-do': 433,
#  'Kukes': 969,
#  'Guangdong': 680,
#  "Sa'dah": 1615,
#  'Lefkosia': 1022,
#  'Limassol': 1038,
#  'Kostroma': 949,
#  'Setubal': 1731,
#  'Mashonaland West': 1149,
#  'Centre': 382,
#  'Kouffo': 952,
#  'North Holland': 1339,
#  'Saxony': 1721,
#  'Goa': 650,
#  'Selangor': 1726,
#  'Baucau': 207,
#  'Jeju-do': 827,
#  'Sila': 1763,
#  'Coquimbo': 464,
#  'Tuscany': 1961,
#  'Tasmania': 1885,
#  'Huila': 760,
#  'Satun': 1717,
#  'Morogoro': 1230,
#  'Ariana': 111,
#  'Black Point': 245,
#  'Banten': 186,
#  'Biobio': 241,
#  'Samut Prakan': 1665,
#  'Santander': 1699,
#  'Sucre': 1838,
#  'Ha Giang': 705,
#  'Hato Mayor': 723,
#  'Laikipia': 1002,
#  'Ucayali': 1966,
#  'Moquegua': 1222,
#  'Kralovehradecky': 957,
#  'Mecklenburg-Vorpommern': 1166,
#  'Northern': 1351,
#  'Phetchabun': 1476,
#  'Banzart': 187,
#  'Vlore': 2048,
#  'Stockholm': 1831,
#  'South Moravian': 1811,
#  'Cherkasy': 408,
#  'Sabana Grande': 1620,
#  'Tlaxcala': 1919,
#  'Central Luzon': 374,
#  'Mangghystau': 1117,
#  'South Sinai': 1813,
#  'Haifa': 711,
#  'Igdir': 774,
#  'Nova Scotia': 1362,
#  "Muhafazat Shamal Sina'": 1241,
#  'Vologda': 2050,
#  'Krasnodarskiy': 961,
#  'Karachayevo-Cherkesiya': 878,
#  'Perm': 1468,
#  'Saint Peter': 1640,
#  'Odessa': 1379,
#  'Zacapa': 2120,
#  'The Marches': 1904,
#  'Moyen-Ogooue': 1235,
#  'Aargau': 2,
#  'Lankaran': 1010,
#  "Vinnyts'ka": 2041,
#  'Picardie': 1488,
#  'Varsinais-Suomi': 2010,
#  'Santarem': 1700,
#  'Altai Krai': 56,
#  'Kankan': 872,
#  'Khakasiya': 907,
#  'Safaqis': 1623,
#  'Andhra Pradesh': 74,
#  'Budva': 293,
#  'West Sumatra': 2080,
#  'Tumbes': 1956,
#  'Gorontalo': 656,
#  'Gaevleborg': 621,
#  'Bayqongyr Qalasy': 214,
#  'South Karelia': 1809,
#  'Kilifi': 930,
#  'Altay': 57,
#  'Soedermanland': 1786,
#  'Temburong': 1897,
#  'Umbria': 1972,
#  'Yuen Long': 2118,
#  'Varna': 2009,
#  'Wanica': 2065,
#  'Assam': 127,
#  'Poltava': 1505,
#  'More og Romsdal': 1227,
#  'Ternopil': 1900,
#  'Trang': 1938,
#  'Samarqand': 1659,
#  'Guantanamo': 683,
#  'Novosibirsk': 1365,
#  'Chernivtsi': 410,
#  'Port Glaud': 1511,
#  'Bengo': 224,
#  'Kakheti': 855,
#  'Sulawesi Tenggara': 1845,
#  'Herrera': 735,
#  'Navarre': 1287,
#  'Khammouan': 908,
#  'Ceara': 361,
#  'Vila Real': 2034,
#  'Ha Tinh': 707,
#  'Ibb': 769,
#  'Madhya Pradesh': 1093,
#  'Bolama and Bijagos': 258,
#  'Santa Catarina': 1694,
#  'Durazno': 540,
#  'Ash Sharqiyah': 125,
#  'Az Zahirah': 152,
#  'Maule': 1159,
#  'Lisbon': 1045,
#  'Dakhlet Nouadhibou': 498,
#  'Maluku Utara': 1110,
#  'Ancash': 71,
#  'Boyaca': 274,
#  'Paraiba': 1443,
#  'Lofa': 1051,
#  'Pando': 1438,
#  'Francisco Morazan': 609,
#  'Binh Thuan': 240,
#  'Vientiane': 2033,
#  'Cauca': 358,
#  'Alta Verapaz': 55,
#  'Far North': 593,
#  'Metlika': 1180,
#  'Castelo Branco': 351,
#  'Leningrad': 1025,
#  'Zanjan': 2132,
#  'Samara': 1658,
#  'Apulia': 90,
#  'Porto': 1513,
#  'Shkoder': 1751,
#  'Silesian Voivodeship': 1764,
#  'Nitriansky': 1320,
#  'Delaware': 509,
#  'Korce': 945,
#  'Fukui': 616,
#  'Eastern Province': 555,
#  'Penza': 1464,
#  'North Karelia': 1341,
#  'Overijssel': 1429,
#  'Khon Kaen': 918,
#  'Guarda': 684,
#  'Jinotega': 838,
#  'Morobe': 1229,
#  'Kosicky': 947,
#  'Grisons': 670,
#  'Alibori': 52,
#  'Banskobystricky': 185,
#  'Manus': 1126,
#  'Tavush': 1888,
#  'Sanliurfa': 1691,
#  'Sardinia': 1714,
#  'OEmnoegovi': 1373,
#  'Khatlon': 913,
#  'Upper Austria': 1974,
#  'Jeollanam-do': 829,
#  'Connecticut': 459,
#  'Coimbra': 451,
#  'Evora': 588,
#  'Sai Kung': 1625,
#  'Vitebsk': 2046,
#  'Kirov': 935,
#  'Calabria': 321,
#  'Inhambane': 794,
#  'Khanh Hoa': 909,
#  'Southern Region': 1824,
#  'Buzau': 309,
#  'Skane': 1777,
#  'Zhejiang Sheng': 2142,
#  'East Java': 546,
#  'Tyrol': 1964,
#  'Aydin': 151,
#  'Subcarpathian Voivodeship': 1835,
#  'Lusaka': 1084,
#  'Salzburg': 1656,
#  'Sao Tome Island': 1709,
#  'Izmir': 818,
#  'Splitsko-Dalmatinska': 1826,
#  'Ulyanovsk': 1970,
#  'North Rhine-Westphalia': 1343,
#  'Ostfold': 1421,
#  'Presovsky': 1524,
#  'Kelantan': 897,
#  'Sud-Comoe': 1841,
#  'Brjansk': 286,
#  'Kwale': 978,
#  'Kowloon City': 955,
#  'North Denmark': 1337,
#  'Kherson': 915,
#  'Sibensko-Kniniska': 1756,
#  'Sha Tin': 1732,
#  'Orenburg': 1411,
#  'Shizuoka': 1750,
#  'Casanare': 349,
#  'Okinawa': 1391,
#  'Balkh': 178,
#  'Gafsa': 622,
#  'Bomet': 260,
#  'Rostov': 1609,
#  'Kara': 876,
#  'Loungnamtha': 1065,
#  'Bas-Sassandra': 197,
#  'West Bengal': 2070,
#  'Rio San Juan': 1595,
#  'El Paraiso': 565,
#  'Battambang': 205,
#  'Southern Highlands': 1819,
#  'Kandal': 870,
#  'Arequipa': 108,
#  'Uttaradit': 1989,
#  'Wong Tai Sin': 2094,
#  'Afar': 16,
#  'Al Wusta': 42,
#  'Kandahar': 869,
#  'Muhafazat ad Dakhiliyah': 1242,
#  'Barahona': 189,
#  'Guatemala': 686,
#  'Masvingo': 1152,
#  'Homa Bay': 749,
#  'Santiago del Estero': 1705,
#  'Riau': 1587,
#  'Ha`apai': 708,
#  'Bimini': 236,
#  'North Bank': 1333,
#  'Coronie': 467,
#  'Araucania': 102,
#  'Los Santos': 1061,
#  'Oued ed Dahab-Lagouira': 1427,
#  'Bicol': 231,
#  'Rogaland': 1605,
#  'Narok': 1283,
#  'NCT': 1257,
#  'Mayaro': 1163,
#  'El Tarf': 567,
#  'Trelawny': 1944,
#  'Makkah': 1104,
#  'Kalmar': 859,
#  'Nakhon Sawan': 1270,
#  'Madriz': 1096,
#  'Kalmykiya': 860,
#  'Central and Western': 381,
#  'Nonthaburi': 1324,
#  'Nan': 1276,
#  'Capital': 336,
#  'Champagne-Ardenne': 397,
#  'Ajaria': 28,
#  'Binh Phuoc': 239,
#  'Bay Islands': 211,
#  'Volgograd': 2049,
#  'Kouilou': 953,
#  'West Nusa Tenggara': 2077,
#  'Beijing': 216,
#  'Ustecky': 1982,
#  'Adana': 11,
#  'Fejer': 599,
#  'East Kalimantan': 547,
#  'Tamuning': 1875,
#  'Isparta': 809,
#  'Cova Lima': 474,
#  'Himachal Pradesh': 741,
#  'Jerusalem': 830,
#  'Lesser Poland Voivodeship': 1027,
#  'Sangre Grande': 1690,
#  'Heilongjiang Sheng': 729,
#  'Saratov': 1712,
#  'Dong Nai': 532,
#  'East Kazakhstan': 548,
#  'Zagrebacka': 2123,
#  'Federation of Bosnia and Herzegovina': 598,
#  'Middle Govi': 1187,
#  'Tongatapu': 1932,
#  'North Central': 1335,
#  'Amapa': 61,
#  'Nyanga': 1371,
#  'Minsk': 1196,
#  'Oppland': 1402,
#  'Jalal-Abad': 821,
#  'Chongqing Shi': 429,
#  'Surin': 1850,
#  'Auvergne': 148,
#  'Daegu': 491,
#  'Meta': 1179,
#  'Mogilev': 1207,
#  'Valparaiso': 2007,
#  'Manyara': 1127,
#  'Yaracuy': 2108,
#  'Keryneia': 903,
#  'Narathiwat': 1281,
#  'Omsk': 1396,
#  'Shida Kartli': 1745,
#  'Huambo': 755,
#  'Malanje': 1107,
#  'Ruvuma': 1613,
#  'Badakhshan': 162,
#  'Vinh Phuc': 2040,
#  'Diego Martin': 517,
#  ...}
